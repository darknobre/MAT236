# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib.cbook import boxplot_stats
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')

# %%
dados.describe()
# Out:
#        CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA     NU_IDADE  \
# count             1.000000e+03       1000.000000  1000.000000
# mean              1.462917e+06         14.627000    20.593000
# std               2.556302e+05          2.551545     5.166822
# min               1.400100e+06         14.000000    14.000000
# 25%               1.400100e+06         14.000000    18.000000
# 50%               1.400100e+06         14.000000    19.000000
# 75%               1.400100e+06         14.000000    21.000000
# max               2.502151e+06         25.000000    62.000000
#
#        CO_MUNICIPIO_NASCIMENTO  CO_UF_NASCIMENTO     CO_ESCOLA  \
# count             9.740000e+02        974.000000  2.700000e+02
# mean              1.696367e+06         16.939425  1.457431e+07
# std               7.210870e+05          7.168607  2.369285e+06
# min               1.100015e+06         11.000000  1.400047e+07
# 25%               1.400100e+06         14.000000  1.400079e+07
# ...

# %%
column1 = dados['Q025']

# %%
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q025']), 1, inplace=True)

# %%
dados
# Out:
#      NU_NOTA_REDACAO Q025
# 0                780  Sim
# 1                900  Sim
# 2                600  Não
# 3                720  Sim
# 4                120  Não
# ..               ...  ...
# 995              660  Sim
# 996              640  Sim
# 997              700  Sim
# 998              840  Sim
# 999              580  Sim
#
# [1000 rows x 2 columns]

# %%
dados.to_csv('Redacao_x_internet.csv',index = False)

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q024']), 1, inplace=True)
dados.to_csv('Redacao_x_computador.csv',index = False)

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q022']), 1, inplace=True)
dados.to_csv('Redacao_x_celular.csv',index = False)

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q009']), 1, inplace=True)
dados.to_csv('Redacao_x_Quartos.csv',index = False)

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q008']), 1, inplace=True)
dados.to_csv('Redacao_x_Banheiro.csv',index = False)

# %%
dados = pd.read_csv("Boa_Vista.csv", sep=',')
dados.drop(dados.columns.difference(['NU_NOTA_REDACAO','Q006']), 1, inplace=True)
dados.to_csv('Redacao_x_renda.csv',index = False)
